# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = r"C:\Users\SHASHANK\OneDrive\Desktop\Evelate labs\HR_Attrition_Analysis\📁 data\HR_data.csv"
df = pd.read_csv(file_path)

# %%
# Attrition distribution
sns.countplot(data=df, x='Attrition')
plt.title('Attrition Count')
plt.show()

# %%
# Department-wise attrition
dept_attrition = pd.crosstab(df['Department'], df['Attrition'], normalize='index')
dept_attrition.plot(kind='bar', stacked=True)
plt.title('Department-wise Attrition')
plt.ylabel('Proportion')
plt.show()

# %%
# Salary Band vs Attrition
if 'MonthlyIncome' in df.columns:
    df['SalaryBand'] = pd.qcut(df['MonthlyIncome'], 4, labels=['Low', 'Medium', 'High', 'Very High'])
    sns.countplot(data=df, x='SalaryBand', hue='Attrition')
    plt.title('Attrition by Salary Band')
    plt.show()

# %%
# Promotions vs Attrition
if 'YearsSinceLastPromotion' in df.columns:
    sns.boxplot(data=df, x='Attrition', y='YearsSinceLastPromotion')
    plt.title('Years Since Last Promotion vs Attrition')
    plt.show()

# %%
# Correlation heatmap
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Feature Correlation')
plt.show()
